# %%
# USAGE
# python text_detection_video.py --east frozen_east_text_detection.pb

# import the necessary packages
from imutils.video import VideoStream
from imutils.video import FPS
from imutils.object_detection import non_max_suppression
import numpy as np
import argparse
import imutils
import time
import cv2
import pytesseract
import math

# %%
def decode_predictions(scores, geometry):
    # grab the number of rows and columns from the scores volume, then
    # initialize our set of bounding box rectangles and corresponding
    # confidence scores
    (numRows, numCols) = scores.shape[2:4]
    rects = []
    confidences = []

    # loop over the number of rows
    for y in range(0, numRows):
        # extract the scores (probabilities), followed by the
        # geometrical data used to derive potential bounding box
        # coordinates that surround text
        scoresData = scores[0, 0, y]
        xData0 = geometry[0, 0, y]
        xData1 = geometry[0, 1, y]
        xData2 = geometry[0, 2, y]
        xData3 = geometry[0, 3, y]
        anglesData = geometry[0, 4, y]

        # loop over the number of columns
        for x in range(0, numCols):
            # if our score does not have sufficient probability,
            # ignore it
            if scoresData[x] < args["min_confidence"]:
                continue

            # compute the offset factor as our resulting feature
            # maps will be 4x smaller than the input image
            (offsetX, offsetY) = (x * 4.0, y * 4.0)

            # extract the rotation angle for the prediction and
            # then compute the sin and cosine
            angle = anglesData[x]
            cos = np.cos(angle)
            sin = np.sin(angle)

            # use the geometry volume to derive the width and height
            # of the bounding box
            h = xData0[x] + xData2[x]
            w = xData1[x] + xData3[x]

            # compute both the starting and ending (x, y)-coordinates
            # for the text prediction bounding box
            endX = int(offsetX + (cos * xData1[x]) + (sin * xData2[x]))
            endY = int(offsetY - (sin * xData1[x]) + (cos * xData2[x]))
            startX = int(endX - w)
            startY = int(endY - h)

            # add the bounding box coordinates and probability score
            # to our respective lists
            rects.append((startX, startY, endX, endY))
            confidences.append(scoresData[x])

    # return a tuple of the bounding boxes and associated confidences
    return (rects, confidences)

# %%
# construct the argument parser and parse the arguments
# ap = argparse.ArgumentParser()
# ap.add_argument("-east", "--east", type=str, required=True,
# 	help="path to input EAST text detector")
# ap.add_argument("-v", "--video", type=str,
# 	help="path to optinal input video file")
# ap.add_argument("-c", "--min-confidence", type=float, default=0.5,
# 	help="minimum probability required to inspect a region")
# ap.add_argument("-w", "--width", type=int, default=320,
# 	help="resized image width (should be multiple of 32)")
# ap.add_argument("-e", "--height", type=int, default=320,
# 	help="resized image height (should be multiple of 32)")
# args = vars(ap.parse_args())

min_confidence = 0.2
width = 640
height = 640
args = { 'east' : './frozen_east_text_detection.pb', 
        'video' : './videos/faster.mp4',
        'min_confidence' : min_confidence,
        'width' : width, 
        'height' : height}

# %%
# initialize the original frame dimensions, new frame dimensions,
# and ratio between the dimensions
(W, H) = (None, None)
(newW, newH) = (args["width"], args["height"])
(rW, rH) = (None, None)

# define the two output layer names for the EAST detector model that
# we are interested -- the first is the output probabilities and the
# second can be used to derive the bounding box coordinates of text
layerNames = [
	"feature_fusion/Conv_7/Sigmoid",
	"feature_fusion/concat_3"]

# %%
# load the pre-trained EAST text detector
print("[INFO] loading EAST text detector...")
net = cv2.dnn.readNet(args["east"])
# Out:
# [INFO] loading EAST text detector...

# %%
# if a video path was not supplied, grab the reference to the web cam
if not args.get("video", False):
	print("[INFO] starting video stream...")
	vs = VideoStream(src=0).start()
	time.sleep(1.0)

# otherwise, grab a reference to the video file
else:
	vs = cv2.VideoCapture(args["video"])

# %%
# start the FPS throughput estimator
fps = FPS().start()

# loop over frames from the video stream
while True:
    # grab the current frame, then handle if we are using a
    # VideoStream or VideoCapture object
    frame = vs.read()
    frame = frame[1] if args.get("video", False) else frame

    # check to see if we have reached the end of the stream
    if frame is None:
        break

    # resize the frame, maintaining the aspect ratio
    frame = imutils.resize(frame, width=1000)
    orig = frame.copy()

    # if our frame dimensions are None, we still need to compute the
    # ratio of old frame dimensions to new frame dimensions
    if W is None or H is None:
        (H, W) = frame.shape[:2]
        rW = W / float(newW)
        rH = H / float(newH)

    # resize the frame, this time ignoring aspect ratio
    frame = cv2.resize(frame, (newW, newH))

    # construct a blob from the frame and then perform a forward pass
    # of the model to obtain the two output layer sets
    blob = cv2.dnn.blobFromImage(frame, 1.0, (newW, newH),
        (123.68, 116.78, 103.94), swapRB=True, crop=False)
    net.setInput(blob)
    (scores, geometry) = net.forward(layerNames)

    # decode the predictions, then  apply non-maxima suppression to
    # suppress weak, overlapping bounding boxes
    (rects, confidences) = decode_predictions(scores, geometry)
    boxes = non_max_suppression(np.array(rects), probs=confidences)

    # loop over the bounding boxes
    #---Tesseract 
    tesseractOutputImage = np.zeros_like(orig)
    origTesseract = orig.copy()
    for (startX, startY, endX, endY) in boxes:
        # scale the bounding box coordinates based on the respective
        # ratios
        startX = int(startX * rW)
        startY = int(startY * rH)
        endX = int(endX * rW)
        endY = int(endY * rH)

        #----tessaract
        extraPixelsX = 0.99
        extraPixelsY = 0.90
        croppedImage = origTesseract[int(startY*extraPixelsY):int(endY/extraPixelsY), int(startX*extraPixelsX):int(endX/extraPixelsX)]
        config = ('-l eng --oem 3 --psm 6')
        pytesseract.pytesseract.tesseract_cmd = r'C:\Users\Roy\AppData\Local\Tesseract-OCR\tesseract.exe'
        text = pytesseract.image_to_string(croppedImage, config=config).encode('utf-8')
        print(startX, startY, endX, endY)
        textScale = (2.0*(endX-startX)/200.0)/(len(text)+0.002)*5
        textThickness = max(4*(endX-startX)/200/(len(text)+1)*4, 0)
        print("Text Scale: ", textScale)
        print("Text Thickness: ", textThickness)
        cv2.putText(tesseractOutputImage, str(text), (startX,endY), cv2.FONT_HERSHEY_SIMPLEX, textScale, (0, 255, 0), int(textThickness), lineType = cv2.LINE_AA)
    #         plt.imshow(croppedImage)
    #         plt.show()
        print("Text:", str(text))


    for (startX, startY, endX, endY) in boxes:
        # scale the bounding box coordinates based on the respective
        # ratios
        startX = int(startX * rW)
        startY = int(startY * rH)
        endX = int(endX * rW)
        endY = int(endY * rH)

        # draw the bounding box on the frame
        cv2.rectangle(orig, (startX, startY), (endX, endY), (0, 255, 0), 2)

    # update the FPS counter
    fps.update()

    # show the output frame
    cv2.imshow("Text Detection", orig)
    cv2.imshow("Text recognition", tesseractOutputImage)
    key = cv2.waitKey(1) & 0xFF

    # if the `q` key was pressed, break from the loop
    if key == ord("q"):
        break

# stop the timer and display FPS information
fps.stop()
print("[INFO] elasped time: {:.2f}".format(fps.elapsed()))
print("[INFO] approx. FPS: {:.2f}".format(fps.fps()))

# if we are using a webcam, release the pointer
if not args.get("video", False):
    vs.stop()

# otherwise, release the file pointer
else:
    vs.release()

# close all windows
cv2.destroyAllWindows()
# Out:
# 643 94 723 110
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.3726595164515542
# Text Thickness:  0.5466666666666666
# Text: b'. EDITION\n\x0c'
# 535 390 657 418
# Text Scale:  0.5544446464279221
# Text Thickness:  0.8133333333333334
# Text: b'ace\nUSIVE\n\x0c'
# 704 391 810 419
# Text Scale:  1.3243378310844578
# Text Thickness:  1.6960000000000002
# Text: b'To\n\x0c'
# 465 430 590 450
# Text Scale:  0.48069527764959236
# Text Thickness:  0.7142857142857143
# Text: b'PEAGCLUSIVE\n\x0c'
# 298 86 384 109
# Text Scale:  0.18694026606382055
# Text Thickness:  0.2866666666666667
# Text: b'eannuenneneent\neT HIF\n\x0c'
# 292 432 384 450
# Text Scale:  0.21902675935625182
# Text Thickness:  0.33454545454545453
# Text: b'AKSHA\nsai) Ta ot\nes\n\x0c'
# 223 36 693 71
# Text Scale:  0.9790850762436465
# Text Thickness:  1.504
# Text: b'@ #AkshavSpeaksToArnab\n\x0c'
# 400 87 589 108
# Text Scale:  0.7268112598061837
# Text Thickness:  1.0799999999999998
# Text: b'NEWS) Aaa 1\n\x0c'
# 364 391 528 420
# Text Scale:  0.5124359455068116
# Text Thickness:  0.7717647058823529
# Text: b'ou\nSUPER EACLI\n\x0c'
# 387 429 471 450
# Text Scale:  0.5998286203941731
# Text Thickness:  0.84
# Text: b'ay\nen\n\x0c'
# 235 86 293 112
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.29991431019708653
# Text Thickness:  0.42
# Text: b'THE\na\n\x0c'
# 643 94 723 110
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 535 390 657 418
# Text Scale:  0.5544446464279221
# Text Thickness:  0.8133333333333334
# Text: b'ace\nUSIVE\n\x0c'
# 704 391 810 419
# Text Scale:  1.3243378310844578
# Text Thickness:  1.6960000000000002
# Text: b'To\n\x0c'
# 298 86 384 109
# Text Scale:  0.614110254213082
# Text Thickness:  0.86
# Text: b'Pt\nri\n\x0c'
# 465 430 590 450
# Text Scale:  0.5207465422429595
# Text Thickness:  0.7692307692307693
# Text: b'PEACLUSIVE\n\x0c'
# 292 432 384 450
# Text Scale:  0.21902675935625182
# Text Thickness:  0.33454545454545453
# Text: b'AKSHA\nsai) Ta ot\nes\n\x0c'
# 225 36 693 71
# Text Scale:  0.9359251259899208
# Text Thickness:  1.44
# Text: b'a) tAkshavSpeaksToArnab\n\x0c'
# 398 87 587 109
# Text Scale:  1.574475174941686
# Text Thickness:  2.1599999999999997
# Text: b'Nisa\n\x0c'
# 365 391 528 420
# Text Scale:  0.4793553699564757
# Text Thickness:  0.7244444444444444
# Text: b'aoa\nSUPER EACLI\n\x0c'
# 387 429 471 450
# Text Scale:  0.46656298600311036
# Text Thickness:  0.6719999999999999
# Text: b'Va\n\xe2\x80\x94_\n\x0c'
# 235 86 293 112
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.17497083819363438
# Text Thickness:  0.25846153846153846
# Text: b'THE\n\xe2\x80\x94\xe2\x80\x94\n\x0c'
# 643 94 721 110
# Text Scale:  3.8922155688622757
# Text Thickness:  3.12
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 535 390 657 418
# Text Scale:  0.5544446464279221
# Text Thickness:  0.8133333333333334
# Text: b'ace\nUSIVE\n\x0c'
# 704 391 810 419
# Text Scale:  1.0595761695321873
# Text Thickness:  1.4133333333333333
# Text: b'tr.\n\x0c'
# 465 430 590 450
# Text Scale:  0.5207465422429595
# Text Thickness:  0.7692307692307693
# Text: b'PEACLUSIVE\n\x0c'
# 292 432 384 450
# Text Scale:  0.21902675935625182
# Text Thickness:  0.33454545454545453
# Text: b'AKSHA\nsai) Ta ot\nes\n\x0c'
# 298 85 384 109
# Text Scale:  0.25291142218562523
# Text Thickness:  0.38222222222222224
# Text: b'eneeennen\neT Ie\n\x0c'
# 226 36 693 71
# Text Scale:  0.43239139291137363
# Text Thickness:  0.6792727272727273
# Text: b'i tte KSI\nHAKSH 21 S| AAC | a\n) #AkshaySpeaksToArnab\n\x0c'
# 398 87 589 109
# Text Scale:  1.1934516370907273
# Text Thickness:  1.6977777777777776
# Text: b'Navara\n\x0c'
# 367 391 528 420
# Text Scale:  0.44717253638484616
# Text Thickness:  0.6778947368421053
# Text: b'mois\nSUPER EACLI\n\x0c'
# 387 429 471 450
# Text Scale:  0.46656298600311036
# Text Thickness:  0.6719999999999999
# Text: b'Va\n\xe2\x80\x94_\n\x0c'
# 235 86 293 112
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.4198320671731307
# Text Thickness:  0.5599999999999999
# Text: b'THE\n\x0c'
# 645 94 723 110
# Text Scale:  3.8922155688622757
# Text Thickness:  3.12
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.3416097317113814
# Text Thickness:  0.5046153846153846
# Text: b'\xe2\x80\x9cEDITION\n\x0c'
# 535 390 657 418
# Text Scale:  0.5544446464279221
# Text Thickness:  0.8133333333333334
# Text: b'ace\nUSIVE\n\x0c'
# 704 391 810 419
# Text Scale:  1.3243378310844578
# Text Thickness:  1.6960000000000002
# Text: b'+,\n\x0c'
# 465 430 590 450
# Text Scale:  0.5207465422429595
# Text Thickness:  0.7692307692307693
# Text: b'PEACLUSIVE\n\x0c'
# 292 432 384 450
# Text Scale:  0.21902675935625182
# Text Thickness:  0.33454545454545453
# Text: b'AKSHA\nsai) Ta ot\nes\n\x0c'
# 296 85 384 109
# Text Scale:  0.628391888031991
# Text Thickness:  0.88
# Text: b'Py\nri\n\x0c'
# 228 36 693 71
# Text Scale:  0.9686692775602035
# Text Thickness:  1.4880000000000002
# Text: b'@ tAkshaySpeaksToArnab\n\x0c'
# 396 87 589 109
# Text Scale:  0.5360515498277969
# Text Thickness:  0.8126315789473684
# Text: b'rie ra INTERVIEW\n\x0c'
# 367 391 528 420
# Text Scale:  0.44717253638484616
# Text Thickness:  0.6778947368421053
# Text: b'meas\nSUPER EACLI\n\x0c'
# 387 429 471 450
# Text Scale:  0.46656298600311036
# Text Thickness:  0.6719999999999999
# Text: b'Va\n\xe2\x80\x94_\n\x0c'
# 235 86 293 111
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.5247376311844077
# Text Thickness:  0.6719999999999999
# Text: b'ie\n\x0c'
# 650 390 703 417
# Text Scale:  0.2649470105978804
# Text Thickness:  0.3854545454545455
# Text: b'\xe2\x80\x94-\nTOs\n\x0c'
# 643 94 723 110
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 535 390 657 418
# Text Scale:  0.5544446464279221
# Text Thickness:  0.8133333333333334
# Text: b'ace\nUSIVE\n\x0c'
# 704 391 810 419
# Text Scale:  1.3243378310844578
# Text Thickness:  1.6960000000000002
# Text: b'Po\n\x0c'
# 465 430 590 450
# Text Scale:  0.5207465422429595
# Text Thickness:  0.7692307692307693
# Text: b'pEACLUSIVE\n\x0c'
# 292 432 384 450
# Text Scale:  0.21902675935625182
# Text Thickness:  0.33454545454545453
# Text: b'AKSHA\nsai) Ta ot\nes\n\x0c'
# 228 36 693 71
# Text Scale:  0.9686692775602035
# Text Thickness:  1.4880000000000002
# Text: b'@ tAkshaySpeaksToArnab\n\x0c'
# 298 85 385 109
# Text Scale:  1.0869565217391306
# Text Thickness:  1.392
# Text: b'my\n\x0c'
# 396 87 589 109
# Text Scale:  1.6077974008663778
# Text Thickness:  2.2057142857142855
# Text: b'Tava\n\x0c'
# 365 391 528 420
# Text Scale:  0.42890222081886115
# Text Thickness:  0.6519999999999999
# Text: b'amass\nSUPER EACLI\n\x0c'
# 387 429 471 450
# Text Scale:  0.46656298600311036
# Text Thickness:  0.6719999999999999
# Text: b'Va\n\xe2\x80\x94_\n\x0c'
# 235 86 293 112
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.5247376311844077
# Text Thickness:  0.6719999999999999
# Text: b'fe\n\x0c'
# 643 94 723 110
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 535 390 657 418
# Text Scale:  0.5544446464279221
# Text Thickness:  0.8133333333333334
# Text: b'ace\nUSIVE\n\x0c'
# 704 391 810 419
# Text Scale:  1.3243378310844578
# Text Thickness:  1.6960000000000002
# Text: b'Po\n\x0c'
# 465 430 590 450
# Text Scale:  0.5207465422429595
# Text Thickness:  0.7692307692307693
# Text: b'pEACLUSIVE\n\x0c'
# 292 432 384 450
# Text Scale:  0.2090719025543133
# Text Thickness:  0.32
# Text: b'AKSHA\nsai 0) Todt\nes\n\x0c'
# 228 36 693 71
# Text Scale:  1.0567221161712572
# Text Thickness:  1.6173913043478263
# Text: b'tAkshaySpeaksToArnab\n\x0c'
# 298 85 384 109
# Text Scale:  0.23886234862793024
# Text Thickness:  0.3621052631578947
# Text: b'eraeuneneest\nTIF\n\x0c'
# 395 87 589 109
# Text Scale:  0.5388290189978892
# Text Thickness:  0.8168421052631579
# Text: b'NEWSY INTERVIEW.\n\x0c'
# 364 391 528 420
# Text Scale:  0.4099590040995901
# Text Thickness:  0.6247619047619047
# Text: b'zzz be\nSUPER EACLI\n\x0c'
# 387 429 471 450
# Text Scale:  0.46656298600311036
# Text Thickness:  0.6719999999999999
# Text: b'Va\n\xe2\x80\x94_\n\x0c'
# 235 86 293 112
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.5247376311844077
# Text Thickness:  0.6719999999999999
# Text: b'it\n\x0c'
# 515 125 778 187
# Text Scale:  13.12375249500998
# Text Thickness:  10.52
# Text: b'\x0c'
# 650 390 703 417
# Text Scale:  0.37846329620108543
# Text Thickness:  0.53
# Text: b'a\nTOs\n\x0c'
# 643 95 723 111
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 535 390 657 418
# Text Scale:  0.5544446464279221
# Text Thickness:  0.8133333333333334
# Text: b'ace\nUSIVE\n\x0c'
# 704 391 810 419
# Text Scale:  1.3243378310844578
# Text Thickness:  1.6960000000000002
# Text: b'Pi\n\x0c'
# 465 430 590 450
# Text Scale:  0.5207465422429595
# Text Thickness:  0.7692307692307693
# Text: b'pEACLUSIVE\n\x0c'
# 292 432 384 450
# Text Scale:  0.2090719025543133
# Text Thickness:  0.32
# Text: b'AKSHA\nsai 0) Todt\nes\n\x0c'
# 228 36 693 71
# Text Scale:  1.0567221161712572
# Text Thickness:  1.6173913043478263
# Text: b'tAkshaySpeaksToArnab\n\x0c'
# 296 85 384 109
# Text Scale:  0.5498625343664083
# Text Thickness:  0.7822222222222223
# Text: b'SL\nTIF\n\x0c'
# 396 87 589 109
# Text Scale:  0.5675802846723915
# Text Thickness:  0.8577777777777778
# Text: b'NEWSY INTERVIEW\n\x0c'
# 364 391 528 420
# Text Scale:  0.4315335227870751
# Text Thickness:  0.6559999999999999
# Text: b'zz be\nSUPER EACLI\n\x0c'
# 387 429 471 450
# Text Scale:  0.46656298600311036
# Text Thickness:  0.6719999999999999
# Text: b'Va\n\xe2\x80\x94_\n\x0c'
# 235 86 293 112
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 193 84 234 112
# Text Scale:  0.2277271717396134
# Text Thickness:  0.32799999999999996
# Text: b'THE\n\xe2\x80\x94\n\x0c'
# 531 126 778 187
# Text Scale:  12.325349301397207
# Text Thickness:  9.88
# Text: b'\x0c'
# 643 95 723 111
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.3726595164515542
# Text Thickness:  0.5466666666666666
# Text: b'5 EDITION\n\x0c'
# 535 390 657 418
# Text Scale:  0.5544446464279221
# Text Thickness:  0.8133333333333334
# Text: b'ace\nUSIVE\n\x0c'
# 704 391 810 419
# Text Scale:  1.3243378310844578
# Text Thickness:  1.6960000000000002
# Text: b'To\n\x0c'
# 465 430 590 450
# Text Scale:  0.5207465422429595
# Text Thickness:  0.7692307692307693
# Text: b'PEACLUSIVE\n\x0c'
# 292 432 384 450
# Text Scale:  0.2090719025543133
# Text Thickness:  0.32
# Text: b'AKSHA\nsai 0) Todt\nes\n\x0c'
# 228 36 693 71
# Text Scale:  1.0567221161712572
# Text Thickness:  1.6173913043478263
# Text: b'tAkshaySpeaksToArnab\n\x0c'
# 298 85 385 109
# Text Scale:  0.1977092991546223
# Text Thickness:  0.3026086956521739
# Text: b'ernennemnenns\neT HIF\n\x0c'
# 396 87 589 109
# Text Scale:  1.9292283086765294
# Text Thickness:  2.5733333333333333
# Text: b'TBM\n\x0c'
# 370 391 528 420
# Text Scale:  0.41574571097779184
# Text Thickness:  0.632
# Text: b'ee ee\nSUPER EACLI\n\x0c'
# 387 429 471 450
# Text Scale:  0.46656298600311036
# Text Thickness:  0.6719999999999999
# Text: b'Va\n\xe2\x80\x94_\n\x0c'
# 235 86 293 112
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.4198320671731307
# Text Thickness:  0.5599999999999999
# Text: b'THE\n\x0c'
# 539 127 779 189
# Text Scale:  1.9993335554815062
# Text Thickness:  2.742857142857143
# Text: b'i. ,\n\x0c'
# 592 89 631 110
# Text Scale:  0.38984406237505
# Text Thickness:  0.52
# Text: b'Ti.\n\x0c'
# 650 390 703 417
# Text Scale:  0.2649470105978804
# Text Thickness:  0.3854545454545455
# Text: b'\xe2\x80\x94-\nTOs\n\x0c'
# 643 95 723 111
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 535 391 659 419
# Text Scale:  0.5635339029267405
# Text Thickness:  0.8266666666666667
# Text: b'yee\nUSIVE\n\x0c'
# 292 432 384 450
# Text Scale:  0.2090719025543133
# Text Thickness:  0.32
# Text: b'AKSHA\nsai 0) Todt\nes\n\x0c'
# 465 430 590 450
# Text Scale:  0.5207465422429595
# Text Thickness:  0.7692307692307693
# Text: b'pEACLUSIVE\n\x0c'
# 296 86 384 110
# Text Scale:  0.36660556573904346
# Text Thickness:  0.5415384615384615
# Text: b'ryt\nCANDID\n\x0c'
# 228 36 693 71
# Text Scale:  1.0567221161712572
# Text Thickness:  1.6173913043478263
# Text: b'tAkshaySpeaksToArnab\n\x0c'
# 373 390 528 419
# Text Scale:  0.43050772136429294
# Text Thickness:  0.6526315789473685
# Text: b'oats\nSUPER EACLI\n\x0c'
# 396 87 589 109
# Text Scale:  1.6077974008663778
# Text Thickness:  2.2057142857142855
# Text: b'MaMa\n\x0c'
# 387 429 471 450
# Text Scale:  0.46656298600311036
# Text Thickness:  0.6719999999999999
# Text: b'Va\n\xe2\x80\x94_\n\x0c'
# 235 86 293 112
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 193 85 234 112
# Text Scale:  0.2927734932876321
# Text Thickness:  0.41
# Text: b'3\n\xe2\x80\x94\n\x0c'
# 553 129 775 189
# Text Scale:  11.077844311377248
# Text Thickness:  8.88
# Text: b'\x0c'
# 593 89 632 110
# Text Scale:  0.6495669553630913
# Text Thickness:  0.78
# Text: b'r\n\x0c'
# 643 95 725 111
# Text Scale:  4.091816367265469
# Text Thickness:  3.28
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.3726595164515542
# Text Thickness:  0.5466666666666666
# Text: b'. EDITION\n\x0c'
# 465 431 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'pEACLUSIVE\n\x0c'
# 292 432 384 450
# Text Scale:  0.2090719025543133
# Text Thickness:  0.32
# Text: b'AKSHA\nsai 0) Todt\nes\n\x0c'
# 296 86 384 110
# Text Scale:  0.5498625343664083
# Text Thickness:  0.7822222222222223
# Text: b'CANDID\n\x0c'
# 228 36 693 71
# Text Scale:  1.0107816711590298
# Text Thickness:  1.55
# Text: b'tAkshavySpeaksToArnab\n\x0c'
# 398 87 589 109
# Text Scale:  1.1934516370907273
# Text Thickness:  1.6977777777777776
# Text: b'Ma Mea\n\x0c'
# 373 391 545 420
# Text Scale:  0.4777246972558605
# Text Thickness:  0.7242105263157894
# Text: b'Bea\nSUPER EACLUS\n\x0c'
# 387 430 470 450
# Text Scale:  0.6914361879373542
# Text Thickness:  0.9485714285714285
# Text: b'A\nae\n\x0c'
# 235 86 293 112
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.4198320671731307
# Text Thickness:  0.5599999999999999
# Text: b'THE\n\x0c'
# 548 130 770 188
# Text Scale:  2.773613193403299
# Text Thickness:  3.5520000000000005
# Text: b'la\n\x0c'
# 593 89 632 110
# Text Scale:  0.32489170276574475
# Text Thickness:  0.44571428571428573
# Text: b'_\xe2\x80\x94\n\x0c'
# 643 95 723 111
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.3726595164515542
# Text Thickness:  0.5466666666666666
# Text: b'. EDITION\n\x0c'
# 290 432 382 450
# Text Scale:  0.2874640669916261
# Text Thickness:  0.4329411764705883
# Text: b'AKSHA\nToate\nes\n\x0c'
# 465 431 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'PEACLUSIVE\n\x0c'
# 389 429 470 449
# Text Scale:  0.2530933633295839
# Text Thickness:  0.38117647058823534
# Text: b'i\nSUPER |\n\xe2\x80\x94)\n\x0c'
# 229 36 693 71
# Text Scale:  1.0086079471350318
# Text Thickness:  1.5466666666666666
# Text: b'tAkshavySpeaksToArnab\n\x0c'
# 295 85 384 110
# Text Scale:  0.4044719141974187
# Text Thickness:  0.5933333333333334
# Text: b'\xe2\x80\x98CANDID\n\x0c'
# 398 87 589 109
# Text Scale:  0.5304966114876125
# Text Thickness:  0.8042105263157895
# Text: b'NEWSY INTERVIEW.\n\x0c'
# 279 388 407 419
# Text Scale:  1.0663112295901367
# Text Thickness:  1.4628571428571429
# Text: b'a\nsi\n\x0c'
# 235 86 292 110
# Text Scale:  2.844311377245509
# Text Thickness:  2.28
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.4198320671731307
# Text Thickness:  0.5599999999999999
# Text: b'THE\n\x0c'
# 535 130 770 189
# Text Scale:  1.6780919737217939
# Text Thickness:  2.35
# Text: b'J \\ |\n\x0c'
# 592 89 632 110
# Text Scale:  0.4997501249375313
# Text Thickness:  0.64
# Text: b'eT\n\x0c'
# 643 95 725 111
# Text Scale:  4.091816367265469
# Text Thickness:  3.28
# Text: b'\x0c'
# 295 432 385 449
# Text Scale:  0.44991001799640074
# Text Thickness:  0.6545454545454545
# Text: b'Taro\nee,\n\x0c'
# 725 94 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 387 430 470 449
# Text Scale:  0.8296681327469012
# Text Thickness:  1.1066666666666667
# Text: b'\xe2\x80\x94\n\x0c'
# 465 431 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'PEACLUSIVE\n\x0c'
# 296 85 384 110
# Text Scale:  0.5498625343664083
# Text Thickness:  0.7822222222222223
# Text: b'CANDID\n\x0c'
# 231 36 693 71
# Text Scale:  0.9624197983501376
# Text Thickness:  1.4784
# Text: b'@ tAkshaySpeaksToArnab\n\x0c'
# 396 87 589 109
# Text Scale:  0.5675802846723915
# Text Thickness:  0.8577777777777778
# Text: b'NEWSY INTERVIEW\n\x0c'
# 237 86 295 110
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 192 84 234 112
# Text Scale:  0.29991431019708653
# Text Thickness:  0.42
# Text: b'THE\na\n\x0c'
# 542 129 768 188
# Text Scale:  2.2590963614554176
# Text Thickness:  3.013333333333333
# Text: b'_ |\n\x0c'
# 592 89 632 110
# Text Scale:  0.6662225183211192
# Text Thickness:  0.8
# Text: b'a\n\x0c'
# 643 95 723 111
# Text Scale:  0.5712653527563554
# Text Thickness:  0.8
# Text: b'SPS |\n\x0c'
# 295 432 385 449
# Text Scale:  0.44991001799640074
# Text Thickness:  0.6545454545454545
# Text: b'Taro\nee,\n\x0c'
# 725 94 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 387 430 470 449
# Text Scale:  0.8296681327469012
# Text Thickness:  1.1066666666666667
# Text: b'\xe2\x80\x94\n\x0c'
# 465 431 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'PEACLUSIVE\n\x0c'
# 298 85 384 110
# Text Scale:  0.5373656585853536
# Text Thickness:  0.7644444444444445
# Text: b'PTT\nrh\n\x0c'
# 231 36 693 71
# Text Scale:  0.9624197983501376
# Text Thickness:  1.4784
# Text: b'@ tAkshaySpeaksToArnab\n\x0c'
# 398 87 589 109
# Text Scale:  1.1934516370907273
# Text Thickness:  1.6977777777777776
# Text: b'Ma. AM\n\x0c'
# 235 86 295 111
# Text Scale:  2.994011976047904
# Text Thickness:  2.4
# Text: b'\x0c'
# 192 85 234 113
# Text Scale:  0.23328149300155518
# Text Thickness:  0.33599999999999997
# Text: b'THE\n\xe2\x80\x94\n\x0c'
# 532 127 767 187
# Text Scale:  2.9360319840079963
# Text Thickness:  3.7600000000000002
# Text: b'2S\n\x0c'
# 592 89 632 110
# Text Scale:  0.6662225183211192
# Text Thickness:  0.8
# Text: b'a\n\x0c'
# 643 95 723 111
# Text Scale:  0.5712653527563554
# Text Thickness:  0.8
# Text: b'Seu |\n\x0c'
# 725 94 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 295 432 385 449
# Text Scale:  0.37493751041493084
# Text Thickness:  0.5538461538461539
# Text: b'}\nTaro\nee,\n\x0c'
# 387 430 470 449
# Text Scale:  0.8296681327469012
# Text Thickness:  1.1066666666666667
# Text: b'\xe2\x80\x94\n\x0c'
# 465 431 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'PEACLUSIVE\n\x0c'
# 231 36 693 71
# Text Scale:  0.9624197983501376
# Text Thickness:  1.4784
# Text: b'@ tAkshaySpeaksToArnab\n\x0c'
# 298 86 384 110
# Text Scale:  0.42991401719656064
# Text Thickness:  0.6254545454545455
# Text: b'Py\nANDID\n\x0c'
# 398 87 587 109
# Text Scale:  1.3496143958868894
# Text Thickness:  1.89
# Text: b'a. AM\n\x0c'
# 235 86 293 111
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 190 85 234 113
# Text Scale:  0.18330278286952173
# Text Thickness:  0.27076923076923076
# Text: b'THE\n\xe2\x80\x94\xe2\x80\x94\n\x0c'
# 518 124 768 186
# Text Scale:  1.2497500499900018
# Text Thickness:  1.8181818181818181
# Text: b'RS\nI \\ |\n\x0c'
# 592 89 632 110
# Text Scale:  0.6662225183211192
# Text Thickness:  0.8
# Text: b'a\n\x0c'
# 642 95 723 112
# Text Scale:  4.041916167664671
# Text Thickness:  3.24
# Text: b'\x0c'
# 723 93 807 111
# Text Scale:  0.3230272265805261
# Text Thickness:  0.48
# Text: b'L EDITION |\n\x0c'
# 292 432 385 450
# Text Scale:  0.4226504271950554
# Text Thickness:  0.62
# Text: b'is\neae\nes\n\x0c'
# 387 429 470 449
# Text Scale:  0.8296681327469012
# Text Thickness:  1.1066666666666667
# Text: b'\xe2\x80\x94\n\x0c'
# 465 431 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'pEACLUSIVE\n\x0c'
# 231 36 693 71
# Text Scale:  0.9624197983501376
# Text Thickness:  1.4784
# Text: b'@ tAkshaySpeaksToArnab\n\x0c'
# 396 87 587 109
# Text Scale:  1.5911362879040318
# Text Thickness:  2.182857142857143
# Text: b'MaMa\n\x0c'
# 296 85 384 110
# Text Scale:  0.4399120175964807
# Text Thickness:  0.64
# Text: b'a\nCANDID\n\x0c'
# 281 389 356 421
# Text Scale:  1.2491672218520986
# Text Thickness:  1.5
# Text: b'=\n\x0c'
# 235 86 293 111
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 190 84 232 112
# Text Scale:  0.4198320671731307
# Text Thickness:  0.5599999999999999
# Text: b'it:\n\x0c'
# 551 129 757 185
# Text Scale:  0.3121022968304951
# Text Thickness:  0.4847058823529412
# Text: b'\xe2\x80\x94_\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\nLo\n\x0c'
# 590 89 632 110
# Text Scale:  0.6995336442371752
# Text Thickness:  0.84
# Text: b'a\n\x0c'
# 643 95 723 112
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 725 93 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 290 432 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPERS\noad\nez,\n\x0c'
# 464 431 592 450
# Text Scale:  0.49223196431318256
# Text Thickness:  0.7314285714285714
# Text: b'LEAGCLUSIVE\n\x0c'
# 229 36 693 71
# Text Scale:  0.9665861178235147
# Text Thickness:  1.4848
# Text: b'@ tAkshaySpeaksToArnab\n\x0c'
# 298 86 384 110
# Text Scale:  0.47767162852699396
# Text Thickness:  0.688
# Text: b'anes\nai\n\x0c'
# 396 87 587 109
# Text Scale:  9.530938123752495
# Text Thickness:  7.64
# Text: b'\x0c'
# 387 429 470 449
# Text Scale:  0.5926878034847186
# Text Thickness:  0.83
# Text: b'I)\nae\n\x0c'
# 279 389 439 418
# Text Scale:  0.9997500624843789
# Text Thickness:  1.4222222222222223
# Text: b'a\nSUPE\n\x0c'
# 235 86 293 111
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 193 85 234 112
# Text Scale:  0.5122438780609695
# Text Thickness:  0.6559999999999999
# Text: b'm3\n\x0c'
# 550 129 751 185
# Text Scale:  0.8373604399266787
# Text Thickness:  1.2369230769230768
# Text: b'a\nRe dette\n\x0c'
# 642 95 723 112
# Text Scale:  4.041916167664671
# Text Thickness:  3.24
# Text: b'\x0c'
# 725 94 806 111
# Text Scale:  0.36811488820214505
# Text Thickness:  0.54
# Text: b'. EDITION\n\x0c'
# 290 432 384 450
# Text Scale:  0.39160139976670555
# Text Thickness:  0.5784615384615385
# Text: b'it\noad\nez,\n\x0c'
# 464 430 592 450
# Text Scale:  0.5332444592567905
# Text Thickness:  0.7876923076923077
# Text: b'LEACLUSIVE\n\x0c'
# 228 36 693 71
# Text Scale:  0.9686692775602035
# Text Thickness:  1.4880000000000002
# Text: b'a tAkshaySpeaksToArnab\n\x0c'
# 298 85 384 110
# Text Scale:  0.42991401719656064
# Text Thickness:  0.6254545454545455
# Text: b'Py\nANDID\n\x0c'
# 395 87 587 109
# Text Scale:  9.580838323353294
# Text Thickness:  7.68
# Text: b'\x0c'
# 387 429 471 449
# Text Scale:  0.38174877295037263
# Text Thickness:  0.5599999999999999
# Text: b'TENE:\n\xe2\x80\x94\n\x0c'
# 454 390 520 418
# Text Scale:  0.20622422197225349
# Text Thickness:  0.31058823529411766
# Text: b'Ball Ka\nR EAGL\n\x0c'
# 273 389 457 419
# Text Scale:  0.5411128102576168
# Text Thickness:  0.8177777777777778
# Text: b'_ aw 2\nSe\nSUPER\n\x0c'
# 235 86 293 111
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 193 85 234 112
# Text Scale:  0.2927734932876321
# Text Thickness:  0.41
# Text: b'THE\na\n\x0c'
# 556 131 748 186
# Text Scale:  0.564639454181861
# Text Thickness:  0.8533333333333333
# Text: b'b=\nDabedeiieten\n\x0c'
# 643 95 725 112
# Text Scale:  4.091816367265469
# Text Thickness:  3.28
# Text: b'\x0c'
# 725 93 806 111
# Text Scale:  0.36811488820214505
# Text Thickness:  0.54
# Text: b'. EDITION\n\x0c'
# 290 432 384 450
# Text Scale:  0.39160139976670555
# Text Thickness:  0.5784615384615385
# Text: b'it\noad\nez,\n\x0c'
# 457 389 578 419
# Text Scale:  0.31838753815387855
# Text Thickness:  0.484
# Text: b'bo oe\nR EACLUSIVE\n\x0c'
# 296 85 385 109
# Text Scale:  0.23418587517103465
# Text Thickness:  0.356
# Text: b'nareenemnense\nwhi\n\x0c'
# 228 36 693 71
# Text Scale:  0.9686692775602035
# Text Thickness:  1.4880000000000002
# Text: b'@ tAkshaySpeaksToArnab\n\x0c'
# 464 430 592 450
# Text Scale:  0.5332444592567905
# Text Thickness:  0.7876923076923077
# Text: b'LEACLUSIVE\n\x0c'
# 398 87 589 109
# Text Scale:  9.530938123752495
# Text Thickness:  7.64
# Text: b'\x0c'
# 387 429 470 449
# Text Scale:  0.34577570404932506
# Text Thickness:  0.5107692307692308
# Text: b'STAR A\n\xe2\x80\x94\n\x0c'
# 273 389 457 419
# Text Scale:  0.4599540045995401
# Text Thickness:  0.700952380952381
# Text: b'_  \xe2\x80\x94\xe2\x80\x94_ |\nSUPER\n\x0c'
# 235 86 293 111
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 193 85 234 112
# Text Scale:  0.2927734932876321
# Text Thickness:  0.41
# Text: b'THE\na\n\x0c'
# 557 131 745 186
# Text Scale:  1.0442123972450565
# Text Thickness:  1.504
# Text: b'_\nre\nTT\n\x0c'
# 643 94 725 111
# Text Scale:  4.091816367265469
# Text Thickness:  3.28
# Text: b'\x0c'
# 723 93 806 111
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'L EDITION\n\x0c'
# 290 432 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPERS\noad\nez,\n\x0c'
# 226 36 693 71
# Text Scale:  0.9728355970335806
# Text Thickness:  1.4944
# Text: b'@ #AkshaySpeaksToArnab\n\x0c'
# 465 430 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'PEACLUSIVE\n\x0c'
# 296 86 384 110
# Text Scale:  0.338409475465313
# Text Thickness:  0.5028571428571429
# Text: b'nome\nCANDID\n\x0c'
# 398 86 587 108
# Text Scale:  1.8892443022790884
# Text Thickness:  2.52
# Text: b'sea\n\x0c'
# 387 429 470 449
# Text Scale:  0.34577570404932506
# Text Thickness:  0.5107692307692308
# Text: b'STAR A\n\xe2\x80\x94\n\x0c'
# 273 389 456 419
# Text Scale:  0.653478074560777
# Text Thickness:  0.9760000000000001
# Text: b"\xe2\x80\x94\ni '\nSUPE\n\x0c"
# 235 87 293 112
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 456 390 628 420
# Text Scale:  0.5374328208973879
# Text Thickness:  0.8094117647058824
# Text: b'no\nR EACLUSIVE\n\x0c'
# 192 85 234 112
# Text Scale:  0.17497083819363438
# Text Thickness:  0.25846153846153846
# Text: b'THE\n\xe2\x80\x94\xe2\x80\x94\n\x0c'
# 554 130 742 185
# Text Scale:  0.7832027995334111
# Text Thickness:  1.156923076923077
# Text: b"ere\nj '? '\n\x0c"
# 643 94 725 111
# Text Scale:  4.091816367265469
# Text Thickness:  3.28
# Text: b'\x0c'
# 723 94 806 111
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'L EDITION\n\x0c'
# 290 432 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPERS\noad\nez,\n\x0c'
# 226 36 693 71
# Text Scale:  0.9728355970335806
# Text Thickness:  1.4944
# Text: b'@ tAkshaySpeaksToArnab\n\x0c'
# 465 430 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'PEACLUSIVE\n\x0c'
# 398 86 587 108
# Text Scale:  1.8892443022790884
# Text Thickness:  2.52
# Text: b'TMs\n\x0c'
# 298 86 384 110
# Text Scale:  1.0744627686156922
# Text Thickness:  1.376
# Text: b'nh\n\x0c'
# 631 390 696 418
# Text Scale:  0.4641530991145387
# Text Thickness:  0.65
# Text: b've\nii\n\x0c'
# 387 429 470 449
# Text Scale:  0.34577570404932506
# Text Thickness:  0.5107692307692308
# Text: b'STAR A\n\xe2\x80\x94\n\x0c'
# 268 390 454 420
# Text Scale:  0.4043126684636119
# Text Thickness:  0.62
# Text: b'==\nDEE\nSUPEF\n\xc2\xa2_ Saal\n\x0c'
# 457 389 612 419
# Text Scale:  0.4078518050731502
# Text Thickness:  0.62
# Text: b'az 6S\nR EACLUSIVE\n\x0c'
# 234 87 293 112
# Text Scale:  2.944111776447106
# Text Thickness:  2.36
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.17497083819363438
# Text Thickness:  0.25846153846153846
# Text: b'THE\n\xe2\x80\x94\xe2\x80\x94\n\x0c'
# 548 129 734 185
# Text Scale:  0.9298140371925614
# Text Thickness:  1.3527272727272728
# Text: b'ee\n, \xe2\x80\x98\n\x0c'
# 687 389 728 421
# Text Scale:  0.2049590081983603
# Text Thickness:  0.29818181818181816
# Text: b'\xe2\x80\x94\n31)3\n\x0c'
# 643 94 725 111
# Text Scale:  4.091816367265469
# Text Thickness:  3.28
# Text: b'\x0c'
# 723 94 806 111
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'L EDITION\n\x0c'
# 290 433 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 631 392 690 418
# Text Scale:  0.36865783554111464
# Text Thickness:  0.5244444444444444
# Text: b'em\nTHE\n\x0c'
# 226 36 693 71
# Text Scale:  0.9728355970335806
# Text Thickness:  1.4944
# Text: b'@ #AkshaySpeaksToArnab\n\x0c'
# 693 390 790 418
# Text Scale:  4.840319361277444
# Text Thickness:  3.88
# Text: b'\x0c'
# 400 86 587 108
# Text Scale:  2.336331834082959
# Text Thickness:  2.992
# Text: b'Ms\n\x0c'
# 465 430 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'PEACLUSIVE\n\x0c'
# 298 86 384 110
# Text Scale:  0.42991401719656064
# Text Thickness:  0.6254545454545455
# Text: b'anne\nayy\n\x0c'
# 385 429 470 449
# Text Scale:  0.42491501699660067
# Text Thickness:  0.6181818181818182
# Text: b'EGE\n\xe2\x80\x94)\n\x0c'
# 268 390 454 420
# Text Scale:  0.4226888464685029
# Text Thickness:  0.6469565217391304
# Text: b'=\nPEF\nSUPEF\n\xc2\xa2_ Saal\n\x0c'
# 457 389 614 419
# Text Scale:  0.35678574675029545
# Text Thickness:  0.5460869565217391
# Text: b'awa \xe2\x80\x9cS\nR EACLUSIVE\n\x0c'
# 234 86 293 111
# Text Scale:  2.944111776447106
# Text Thickness:  2.36
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.17497083819363438
# Text Thickness:  0.25846153846153846
# Text: b'THE\n\xe2\x80\x94\xe2\x80\x94\n\x0c'
# 546 128 734 185
# Text Scale:  1.5661446184605132
# Text Thickness:  2.1485714285714286
# Text: b'a\n/_\n\x0c'
# 643 95 725 111
# Text Scale:  4.091816367265469
# Text Thickness:  3.28
# Text: b'\x0c'
# 723 94 806 111
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'L EDITION\n\x0c'
# 692 391 810 418
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 433 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 629 392 690 418
# Text Scale:  0.3049390121975605
# Text Thickness:  0.4436363636363636
# Text: b'saan\nTHE\n\x0c'
# 226 36 693 71
# Text Scale:  0.9728355970335806
# Text Thickness:  1.4944
# Text: b'@ #AkshaySpeaksToArnab\n\x0c'
# 400 86 589 108
# Text Scale:  1.1809547613096725
# Text Thickness:  1.68
# Text: b'TMs\nra\n\x0c'
# 467 429 596 448
# Text Scale:  0.5862570441737865
# Text Thickness:  0.86
# Text: b'EXCLUSIVE\n\x0c'
# 296 86 384 110
# Text Scale:  0.3142408227396086
# Text Thickness:  0.4693333333333333
# Text: b'oeeemenn\nayy\n\x0c'
# 385 429 470 449
# Text Scale:  0.42491501699660067
# Text Thickness:  0.6181818181818182
# Text: b'EGE\n\xe2\x80\x94)\n\x0c'
# 268 390 454 420
# Text Scale:  0.4043126684636119
# Text Thickness:  0.62
# Text: b'ax\nPER\nSUPEF\n\xc2\xa2_ Saal\n\x0c'
# 456 389 612 419
# Text Scale:  0.3713932006475574
# Text Thickness:  0.5672727272727273
# Text: b'aw \xe2\x80\x9c=\nR EACLUSIVE\n\x0c'
# 235 87 293 111
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 190 84 232 112
# Text Scale:  0.4198320671731307
# Text Thickness:  0.5599999999999999
# Text: b'it:\n\x0c'
# 548 129 729 185
# Text Scale:  0.8225777131430649
# Text Thickness:  1.2066666666666668
# Text: b'\xe2\x80\x94\xe2\x80\x94\nwe\n\x0c'
# 643 95 725 111
# Text Scale:  4.091816367265469
# Text Thickness:  3.28
# Text: b'\x0c'
# 723 94 806 111
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'L EDITION\n\x0c'
# 692 391 810 418
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 433 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 631 392 690 418
# Text Scale:  0.32770495445456566
# Text Thickness:  0.472
# Text: b'hem\nTHE\n\x0c'
# 226 36 693 71
# Text Scale:  0.9728355970335806
# Text Thickness:  1.4944
# Text: b'@ #AkshaySpeaksToArnab\n\x0c'
# 400 86 589 108
# Text Scale:  9.431137724550897
# Text Thickness:  7.56
# Text: b'\x0c'
# 467 429 596 448
# Text Scale:  0.5862570441737865
# Text Thickness:  0.86
# Text: b'EXCLUSIVE\n\x0c'
# 296 85 384 109
# Text Scale:  0.48878027105087757
# Text Thickness:  0.704
# Text: b'cee\neye\n\x0c'
# 385 429 470 449
# Text Scale:  0.42491501699660067
# Text Thickness:  0.6181818181818182
# Text: b'EGE\n\xe2\x80\x94)\n\x0c'
# 275 390 457 419
# Text Scale:  0.758206965505749
# Text Thickness:  1.12
# Text: b'=\nPE\nSUPER\n\x0c'
# 456 389 612 419
# Text Scale:  0.3391009477436745
# Text Thickness:  0.52
# Text: b'26a \xe2\x80\x9cSe\nR EACLUSIVE\n\x0c'
# 234 86 293 111
# Text Scale:  2.944111776447106
# Text Thickness:  2.36
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.29991431019708653
# Text Thickness:  0.42
# Text: b'THE\na\n\x0c'
# 551 128 728 183
# Text Scale:  1.4745084971676108
# Text Thickness:  2.0228571428571427
# Text: b'i\n},\n\x0c'
# 645 95 725 111
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 723 94 806 111
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'L EDITION\n\x0c'
# 692 390 810 418
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 433 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 629 392 690 418
# Text Scale:  0.3388135969784492
# Text Thickness:  0.488
# Text: b'aes\nTHE\n\x0c'
# 400 86 587 108
# Text Scale:  1.1684578855286178
# Text Thickness:  1.6622222222222223
# Text: b'MAM aa\n\x0c'
# 225 36 693 71
# Text Scale:  0.9749187567702691
# Text Thickness:  1.4975999999999998
# Text: b'a tAkshaySpeaksToArnab\n\x0c'
# 467 429 596 448
# Text Scale:  0.5862570441737865
# Text Thickness:  0.86
# Text: b'EXCLUSIVE\n\x0c'
# 296 86 384 109
# Text Scale:  0.628391888031991
# Text Thickness:  0.88
# Text: b'ae\nyy\n\x0c'
# 385 429 470 449
# Text Scale:  0.42491501699660067
# Text Thickness:  0.6181818181818182
# Text: b'EGE\n\xe2\x80\x94)\n\x0c'
# 275 389 457 419
# Text Scale:  0.6065857885615251
# Text Thickness:  0.91
# Text: b'> a\nDEE\nSUPER\n\x0c'
# 456 389 610 419
# Text Scale:  0.34996818471048086
# Text Thickness:  0.5356521739130435
# Text: b'a4 \xe2\x80\x9cSe\nR EACLUSIVE\n\x0c'
# 234 86 293 111
# Text Scale:  2.944111776447106
# Text Thickness:  2.36
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.2624343914021494
# Text Thickness:  0.3733333333333333
# Text: b'THE\nsl\n\x0c'
# 553 127 729 182
# Text Scale:  0.676818950930626
# Text Thickness:  1.0057142857142858
# Text: b'at\n\xe2\x80\x94s\nJ a\n\x0c'
# 645 95 725 111
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 723 94 806 111
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'L EDITION\n\x0c'
# 692 391 810 419
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 433 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 400 86 589 108
# Text Scale:  0.7873687718713547
# Text Thickness:  1.1630769230769231
# Text: b'Mavala\nNEV\n\x0c'
# 629 392 690 418
# Text Scale:  0.38115471132216944
# Text Thickness:  0.5422222222222222
# Text: b'ae\nTHE\n\x0c'
# 226 36 693 71
# Text Scale:  0.9728355970335806
# Text Thickness:  1.4944
# Text: b'@ #AkshaySpeaksToArnab\n\x0c'
# 298 86 382 108
# Text Scale:  4.191616766467066
# Text Thickness:  3.36
# Text: b'\x0c'
# 467 429 596 448
# Text Scale:  0.5862570441737865
# Text Thickness:  0.86
# Text: b'EXCLUSIVE\n\x0c'
# 275 390 457 419
# Text Scale:  0.9098180363927215
# Text Thickness:  1.3236363636363637
# Text: b'[I\nSUPER\n\x0c'
# 385 429 470 449
# Text Scale:  0.42491501699660067
# Text Thickness:  0.6181818181818182
# Text: b'EGE\n\xe2\x80\x94)\n\x0c'
# 456 389 610 419
# Text Scale:  0.34996818471048086
# Text Thickness:  0.5356521739130435
# Text: b'ai \xe2\x80\x9cSe\nR EACLUSIVE\n\x0c'
# 234 86 293 111
# Text Scale:  2.944111776447106
# Text Thickness:  2.36
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.2624343914021494
# Text Thickness:  0.3733333333333333
# Text: b'THE\nsl\n\x0c'
# 557 129 725 182
# Text Scale:  0.3817834742296155
# Text Thickness:  0.5843478260869565
# Text: b'a \xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94_ an\n.\n\x0c'
# 645 95 725 111
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 723 94 806 111
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'L EDITION\n\x0c'
# 692 390 810 418
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 433 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 228 36 693 71
# Text Scale:  1.0567221161712572
# Text Thickness:  1.6173913043478263
# Text: b'#AkshaySpeaksToArnab\n\x0c'
# 298 85 382 108
# Text Scale:  0.5998286203941731
# Text Thickness:  0.84
# Text: b'PETTY\n\x0c'
# 401 86 589 108
# Text Scale:  0.5528761322197389
# Text Thickness:  0.8355555555555555
# Text: b'NEWSY INTERVIEW\n\x0c'
# 629 392 690 418
# Text Scale:  0.3388135969784492
# Text Thickness:  0.488
# Text: b'\xe2\x80\x94\nTHE\n\x0c'
# 467 429 596 448
# Text Scale:  0.5862570441737865
# Text Thickness:  0.86
# Text: b'EXCLUSIVE\n\x0c'
# 268 389 456 419
# Text Scale:  0.3032062447584027
# Text Thickness:  0.47
# Text: b'I\nnana na SESE\nTy:\nSUPER\n_ tt\n\x0c'
# 385 429 470 449
# Text Scale:  0.42491501699660067
# Text Thickness:  0.6181818181818182
# Text: b'EGE\n\xe2\x80\x94)\n\x0c'
# 456 389 609 419
# Text Scale:  0.4025892011367225
# Text Thickness:  0.612
# Text: b'a4 Vs\nR EACLUSIVE\n\x0c'
# 235 87 293 111
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.4198320671731307
# Text Thickness:  0.5599999999999999
# Text: b'3\na\n\x0c'
# 554 128 723 183
# Text Scale:  0.6034852163976574
# Text Thickness:  0.9013333333333333
# Text: b'NN SS eel\nwe\n\x0c'
# 645 95 725 111
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 723 94 806 111
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'L EDITION\n\x0c'
# 692 390 810 418
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 433 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 226 36 693 71
# Text Scale:  0.9728355970335806
# Text Thickness:  1.4944
# Text: b'@ #AkshaySpeaksToArnab\n\x0c'
# 400 86 589 108
# Text Scale:  9.431137724550897
# Text Thickness:  7.56
# Text: b'\x0c'
# 629 392 690 418
# Text Scale:  0.3388135969784492
# Text Thickness:  0.488
# Text: b'\xe2\x80\x94\nTHE\n\x0c'
# 296 85 382 109
# Text Scale:  0.716427857380873
# Text Thickness:  0.9828571428571429
# Text: b'nine\n\x0c'
# 467 429 596 448
# Text Scale:  0.5862570441737865
# Text Thickness:  0.86
# Text: b'EXCLUSIVE\n\x0c'
# 385 429 470 449
# Text Scale:  0.4721173072650522
# Text Thickness:  0.6799999999999999
# Text: b'EGE\n\xe2\x80\x94\n\x0c'
# 273 389 457 419
# Text Scale:  1.0219951121972894
# Text Thickness:  1.472
# Text: b'1\nSUPER\n\x0c'
# 456 389 609 419
# Text Scale:  0.4025892011367225
# Text Thickness:  0.612
# Text: b'i+ So\nR EACLUSIVE\n\x0c'
# 234 86 293 111
# Text Scale:  2.944111776447106
# Text Thickness:  2.36
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.20995800839832032
# Text Thickness:  0.3054545454545454
# Text: b'3\n\xe2\x80\x94\xe2\x80\x94\n\x0c'
# 571 127 726 180
# Text Scale:  0.7748450309938013
# Text Thickness:  1.1272727272727272
# Text: b'Se\n\xe2\x80\x94\n7\n\x0c'
# 645 95 725 111
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 723 94 806 111
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'L EDITION\n\x0c'
# 692 390 810 418
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 433 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 295 86 382 110
# Text Scale:  0.48322594978893574
# Text Thickness:  0.696
# Text: b'anne\nmy\n\x0c'
# 228 36 693 71
# Text Scale:  1.0567221161712572
# Text Thickness:  1.6173913043478263
# Text: b'#AkshaySpeaksToArnab\n\x0c'
# 401 84 600 105
# Text Scale:  1.1053099311264163
# Text Thickness:  1.592
# Text: b'MaMa ae\n\x0c'
# 629 392 690 418
# Text Scale:  0.3388135969784492
# Text Thickness:  0.488
# Text: b'cae\nTHE\n\x0c'
# 465 430 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'PEACLUSIVE\n\x0c'
# 385 429 470 449
# Text Scale:  0.4721173072650522
# Text Thickness:  0.6799999999999999
# Text: b'EGE\n\xe2\x80\x94\n\x0c'
# 273 389 457 419
# Text Scale:  0.7075834487002
# Text Thickness:  1.0514285714285714
# Text: b'a\nDEE\nSUPER\n\x0c'
# 456 389 609 419
# Text Scale:  0.47806524184476945
# Text Thickness:  0.72
# Text: b'cf\nR EACLUSIVE\n\x0c'
# 235 86 295 111
# Text Scale:  2.994011976047904
# Text Thickness:  2.4
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.20995800839832032
# Text Thickness:  0.3054545454545454
# Text: b'3\n\xe2\x80\x94\xe2\x80\x94\n\x0c'
# 562 127 728 184
# Text Scale:  0.3772384328697391
# Text Thickness:  0.577391304347826
# Text: b'_  \xe2\x80\x94_\xe2\x80\x94\xe2\x80\x94 2\n_\n_.\n\x0c'
# 643 95 723 111
# Text Scale:  3.992015968063872
# Text Thickness:  3.2
# Text: b'\x0c'
# 723 94 806 111
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'L EDITION\n\x0c'
# 692 390 810 418
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 433 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 296 85 384 110
# Text Scale:  0.5498625343664083
# Text Thickness:  0.7822222222222223
# Text: b'cee\nyy\n\x0c'
# 226 36 693 71
# Text Scale:  0.9728355970335806
# Text Thickness:  1.4944
# Text: b'@ #AkshaySpeaksToArnab\n\x0c'
# 401 83 600 105
# Text Scale:  0.5852252676155747
# Text Thickness:  0.8844444444444445
# Text: b'72 \\ matt Ma hi\n\x0c'
# 629 391 690 418
# Text Scale:  0.4355898314767209
# Text Thickness:  0.61
# Text: b'an\nim\n\x0c'
# 465 430 595 450
# Text Scale:  0.5415764039326778
# Text Thickness:  0.8
# Text: b'PEACLUSIVE\n\x0c'
# 387 429 470 449
# Text Scale:  0.34577570404932506
# Text Thickness:  0.5107692307692308
# Text: b'STAR A\n\xe2\x80\x94\n\x0c'
# 456 389 607 419
# Text Scale:  0.41939784468392405
# Text Thickness:  0.6357894736842106
# Text: b'7 Ve\nR EACLUSIVE\n\x0c'
# 273 389 457 419
# Text Scale:  0.5749281339832522
# Text Thickness:  0.8658823529411765
# Text: b"> |e\n| '\nSUPER\n\x0c"
# 239 86 293 110
# Text Scale:  2.694610778443114
# Text Thickness:  2.16
# Text: b'\x0c'
# 192 85 234 112
# Text Scale:  0.4198320671731307
# Text Thickness:  0.5599999999999999
# Text: b'THE\n\x0c'
# 556 126 756 183
# Text Scale:  0.9089256498818397
# Text Thickness:  1.3333333333333333
# Text: b'i\nOO _.\nq\n\x0c'
# 643 95 725 111
# Text Scale:  4.091816367265469
# Text Thickness:  3.28
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 692 390 810 418
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 432 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 298 86 384 110
# Text Scale:  0.42991401719656064
# Text Thickness:  0.6254545454545455
# Text: b'acme\nayy\n\x0c'
# 223 36 693 71
# Text Scale:  0.6911358155402624
# Text Thickness:  1.0742857142857143
# Text: b'@ tAkshaySpt pal Ks\xe2\x80\x99 rol Arnab\n\x0c'
# 629 392 690 418
# Text Scale:  0.4355898314767209
# Text Thickness:  0.61
# Text: b'es\nim\n\x0c'
# 465 430 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'PEACLUSIVE\n\x0c'
# 401 83 598 105
# Text Scale:  0.5183664877381329
# Text Thickness:  0.788
# Text: b'NEWSY INTERVIEW |\n\x0c'
# 385 429 470 449
# Text Scale:  0.4721173072650522
# Text Thickness:  0.6799999999999999
# Text: b'EGE\n\xe2\x80\x94\n\x0c'
# 457 389 609 419
# Text Scale:  0.39995789916850866
# Text Thickness:  0.608
# Text: b'7, Ve\nR EACLUSIVE\n\x0c'
# 273 389 457 419
# Text Scale:  0.5411128102576168
# Text Thickness:  0.8177777777777778
# Text: b'_\nAd\nCosa SUPER\n\x0c'
# 237 86 293 109
# Text Scale:  2.7944111776447107
# Text Thickness:  2.24
# Text: b'\x0c'
# 190 85 234 112
# Text Scale:  0.5497251374312844
# Text Thickness:  0.704
# Text: b'm3\n\x0c'
# 537 128 771 184
# Text Scale:  1.4621344663834042
# Text Thickness:  2.08
# Text: b'ave- 4\n\x0c'
# 643 94 725 111
# Text Scale:  4.091816367265469
# Text Thickness:  3.28
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.31533610213813257
# Text Thickness:  0.4685714285714285
# Text: b'. EDITION |\n\x0c'
# 692 391 810 419
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 432 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 629 392 690 418
# Text Scale:  0.38115471132216944
# Text Thickness:  0.5422222222222222
# Text: b'ae\nTHE\n\x0c'
# 298 86 384 110
# Text Scale:  0.42991401719656064
# Text Thickness:  0.6254545454545455
# Text: b'acme\nath\n\x0c'
# 223 36 693 71
# Text Scale:  0.7832811145923606
# Text Thickness:  1.2129032258064516
# Text: b'a tAkshe yS ne pak (sToArnab\n\x0c'
# 464 430 595 450
# Text Scale:  0.5457423762706216
# Text Thickness:  0.8061538461538462
# Text: b'LEACLUSIVE\n\x0c'
# 401 84 595 106
# Text Scale:  0.5104725818334912
# Text Thickness:  0.776
# Text: b'NEWSY INTERVIEW |\n\x0c'
# 271 389 456 419
# Text Scale:  0.44043424435768025
# Text Thickness:  0.6727272727272727
# Text: b"=\nre '\nSUPE\nbeneath\n\x0c"
# 387 429 470 449
# Text Scale:  0.34577570404932506
# Text Thickness:  0.5107692307692308
# Text: b'STAR A\n\xe2\x80\x94\n\x0c'
# 456 389 610 419
# Text Scale:  0.40522050310493635
# Text Thickness:  0.616
# Text: b'7. Ve\nR EACLUSIVE\n\x0c'
# 235 86 295 110
# Text Scale:  2.994011976047904
# Text Thickness:  2.4
# Text: b'\x0c'
# 190 85 234 112
# Text Scale:  0.18330278286952173
# Text Thickness:  0.27076923076923076
# Text: b'THE\n\xe2\x80\x94\xe2\x80\x94\n\x0c'
# 535 127 770 183
# Text Scale:  2.3490603758496604
# Text Thickness:  3.1333333333333333
# Text: b'Pa)\n\x0c'
# 642 94 725 111
# Text Scale:  0.8296681327469012
# Text Thickness:  1.1066666666666667
# Text: b', a\n\x0c'
# 725 94 807 111
# Text Scale:  0.3726595164515542
# Text Thickness:  0.5466666666666666
# Text: b'. EDITION\n\x0c'
# 692 391 810 419
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 433 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 629 392 690 418
# Text Scale:  0.38115471132216944
# Text Thickness:  0.5422222222222222
# Text: b'aes\nim\n\x0c'
# 296 86 382 110
# Text Scale:  0.42991401719656064
# Text Thickness:  0.6254545454545455
# Text: b'onan\nath\n\x0c'
# 226 36 693 71
# Text Scale:  0.9728355970335806
# Text Thickness:  1.4944
# Text: b'@ #AkshaySpeaksToArnab\n\x0c'
# 401 84 600 106
# Text Scale:  9.930139720558882
# Text Thickness:  7.96
# Text: b'\x0c'
# 465 430 596 450
# Text Scale:  0.5457423762706216
# Text Thickness:  0.8061538461538462
# Text: b'PEACLUSIVE\n\x0c'
# 271 389 456 419
# Text Scale:  0.3425672172431672
# Text Thickness:  0.5285714285714286
# Text: b"\xe2\x80\x94\xe2\x80\x94\nre '\nSUPER\nbeneath\n\x0c"
# 387 429 470 449
# Text Scale:  0.34577570404932506
# Text Thickness:  0.5107692307692308
# Text: b'STAR A\n\xe2\x80\x94\n\x0c'
# 457 389 610 419
# Text Scale:  0.36425102371202744
# Text Thickness:  0.5563636363636364
# Text: b'- 2. Va\nR EACLUSIVE\n\x0c'
# 235 87 293 111
# Text Scale:  0.22304260882941085
# Text Thickness:  0.3314285714285714
# Text: b"\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\n'\n\x0c"
# 190 84 234 112
# Text Scale:  0.5497251374312844
# Text Thickness:  0.704
# Text: b'in\n\x0c'
# 545 129 768 182
# Text Scale:  1.857714095301566
# Text Thickness:  2.5485714285714285
# Text: b'Ass)\n\x0c'
# 642 96 725 112
# Text Scale:  4.1417165668662665
# Text Thickness:  3.32
# Text: b'\x0c'
# 725 94 807 111
# Text Scale:  0.3726595164515542
# Text Thickness:  0.5466666666666666
# Text: b'. EDITION\n\x0c'
# 692 391 810 419
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 433 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 401 84 603 106
# Text Scale:  1.1219728949122416
# Text Thickness:  1.616
# Text: b'Mada ae\n\x0c'
# 296 85 382 109
# Text Scale:  0.716427857380873
# Text Thickness:  0.9828571428571429
# Text: b'a\nai\n\x0c'
# 629 391 692 418
# Text Scale:  0.34992223950233275
# Text Thickness:  0.504
# Text: b'care\nin\n\x0c'
# 228 36 693 71
# Text Scale:  0.9686692775602035
# Text Thickness:  1.4880000000000002
# Text: b'@ tAkshaySpeaksToArnab\n\x0c'
# 464 430 595 450
# Text Scale:  0.5457423762706216
# Text Thickness:  0.8061538461538462
# Text: b'LEACLUSIVE\n\x0c'
# 457 389 607 419
# Text Scale:  0.35710884677649746
# Text Thickness:  0.5454545454545454
# Text: b'- /. Va\nR EACLUSIVE\n\x0c'
# 273 389 456 419
# Text Scale:  0.5718035245594302
# Text Thickness:  0.8611764705882353
# Text: b"\xe2\x80\x94\nre '\nSUPER\n\x0c"
# 387 429 470 449
# Text Scale:  0.34577570404932506
# Text Thickness:  0.5107692307692308
# Text: b'STAR A\n\xe2\x80\x94\n\x0c'
# 235 86 293 111
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 190 84 234 112
# Text Scale:  0.43982407037185134
# Text Thickness:  0.5866666666666667
# Text: b'in:\n\x0c'
# 539 128 768 183
# Text Scale:  11.427145708582835
# Text Thickness:  9.16
# Text: b'\x0c'
# 642 96 725 112
# Text Scale:  1.3824117255163224
# Text Thickness:  1.66
# Text: b';\n\x0c'
# 723 94 807 111
# Text Scale:  0.38174877295037263
# Text Thickness:  0.5599999999999999
# Text: b'L EDITION\n\x0c'
# 692 391 810 419
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 432 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 298 85 382 109
# Text Scale:  0.5998286203941731
# Text Thickness:  0.84
# Text: b'SS\neT\n\x0c'
# 401 84 603 106
# Text Scale:  1.0097980403919216
# Text Thickness:  1.469090909090909
# Text: b'Mavala a\n\x0c'
# 628 391 690 418
# Text Scale:  0.38740314921269675
# Text Thickness:  0.5511111111111111
# Text: b'\xe2\x80\x94\nim\n\x0c'
# 228 36 693 71
# Text Scale:  0.9686692775602035
# Text Thickness:  1.4880000000000002
# Text: b'@ tAkshaySpeaksToArnab\n\x0c'
# 465 430 595 450
# Text Scale:  0.5415764039326778
# Text Thickness:  0.8
# Text: b'PEACLUSIVE\n\x0c'
# 271 389 456 419
# Text Scale:  0.3083127791480568
# Text Thickness:  0.4774193548387097
# Text: b'\xe2\x80\x94  \xe2\x80\x94_>\nry4:\nSUPER\nhelena\n\x0c'
# 456 389 609 419
# Text Scale:  0.4499470650511705
# Text Thickness:  0.68
# Text: b'- /\nR EACLUSIVE\n\x0c'
# 387 429 470 449
# Text Scale:  0.34577570404932506
# Text Thickness:  0.5107692307692308
# Text: b'STAR A\n\xe2\x80\x94\n\x0c'
# 235 86 293 111
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 189 84 232 112
# Text Scale:  0.42982806877249097
# Text Thickness:  0.5733333333333334
# Text: b'THE\n\x0c'
# 562 129 757 180
# Text Scale:  3.2478347768154565
# Text Thickness:  3.9
# Text: b'|\n\x0c'
# 642 94 723 111
# Text Scale:  4.041916167664671
# Text Thickness:  3.24
# Text: b'\x0c'
# 721 93 807 111
# Text Scale:  0.42991401719656064
# Text Thickness:  0.6254545454545455
# Text: b'LEDITION\n\x0c'
# 692 390 810 418
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 432 384 450
# Text Scale:  0.3614828487924934
# Text Thickness:  0.5371428571428571
# Text: b'ais\noad\nez,\n\x0c'
# 403 85 571 107
# Text Scale:  0.4940595224091283
# Text Thickness:  0.7466666666666666
# Text: b'NEWSY INTERVIE\\\n\x0c'
# 628 391 690 418
# Text Scale:  0.38740314921269675
# Text Thickness:  0.5511111111111111
# Text: b'\xe2\x80\x94\nim\n\x0c'
# 298 86 382 110
# Text Scale:  0.24702976120456416
# Text Thickness:  0.3733333333333333
# Text: b'ormemnenn\nwhiny\n\x0c'
# 465 430 595 450
# Text Scale:  0.5415764039326778
# Text Thickness:  0.8
# Text: b'pEACLUSIVE\n\x0c'
# 456 389 607 419
# Text Scale:  0.39732659720029473
# Text Thickness:  0.604
# Text: b'Tr oi\nR EACLUSIVE\n\x0c'
# 271 389 456 419
# Text Scale:  0.44043424435768025
# Text Thickness:  0.6727272727272727
# Text: b'1 =\nDEE\nSUPER\nenema\n\x0c'
# 387 429 470 449
# Text Scale:  0.34577570404932506
# Text Thickness:  0.5107692307692308
# Text: b'STAR A\n\xe2\x80\x94\n\x0c'
# 257 35 618 71
# Text Scale:  0.340553186672201
# Text Thickness:  0.5348148148148147
# Text: b'! wOonaalvci nih\nET (Ss r 3 yspeakKsSioA\nTARSIIA YI\n\x0c'
# 237 86 295 111
# Text Scale:  2.894211576846307
# Text Thickness:  2.32
# Text: b'\x0c'
# 190 84 232 112
# Text Scale:  0.4198320671731307
# Text Thickness:  0.5599999999999999
# Text: b'tt:\n\x0c'
# 579 129 750 182
# Text Scale:  0.9497889357920462
# Text Thickness:  1.3679999999999999
# Text: b'a.\n. me\n\x0c'
# 642 95 725 112
# Text Scale:  4.1417165668662665
# Text Thickness:  3.32
# Text: b'\x0c'
# 721 93 807 111
# Text Scale:  0.42991401719656064
# Text Thickness:  0.6254545454545455
# Text: b'LEDITION\n\x0c'
# 401 86 501 108
# Text Scale:  0.6248437890527367
# Text Thickness:  0.8888888888888888
# Text: b'a Salt\n\x0c'
# 692 391 810 419
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 432 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 503 86 587 108
# Text Scale:  1.0494752623688155
# Text Thickness:  1.3439999999999999
# Text: b'aa\n\x0c'
# 629 391 690 418
# Text Scale:  0.4355898314767209
# Text Thickness:  0.61
# Text: b'een\ni\n\x0c'
# 465 430 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'PEACLUSIVE\n\x0c'
# 295 85 382 109
# Text Scale:  0.3345639132441163
# Text Thickness:  0.49714285714285716
# Text: b'eemennes\nny\n\x0c'
# 456 389 606 419
# Text Scale:  0.4411245735795789
# Text Thickness:  0.6666666666666666
# Text: b'r i\nR EACLUSIVE\n\x0c'
# 271 389 456 419
# Text Scale:  0.40213894443961395
# Text Thickness:  0.6166666666666667
# Text: b'a al\nDEE\nSUPER\nhelena\n\x0c'
# 387 429 470 449
# Text Scale:  0.34577570404932506
# Text Thickness:  0.5107692307692308
# Text: b'STAR A\n\xe2\x80\x94\n\x0c'
# 239 86 293 110
# Text Scale:  2.694610778443114
# Text Thickness:  2.16
# Text: b'\x0c'
# 265 37 487 73
# Text Scale:  0.8537148131056761
# Text Thickness:  1.2685714285714287
# Text: b' #AkshaySpe\n\x0c'
# 192 85 234 112
# Text Scale:  0.29991431019708653
# Text Thickness:  0.42
# Text: b'THE\na\n\x0c'
# 595 89 635 110
# Text Scale:  0.2856326763781777
# Text Thickness:  0.4
# Text: b'\xe2\x80\x9cRt\n\x0c'
# 640 95 723 112
# Text Scale:  0.4149170165966806
# Text Thickness:  0.6036363636363636
# Text: b'\xe2\x80\x9cSPECI\n\x0c'
# 393 86 495 108
# Text Scale:  5.089820359281437
# Text Thickness:  4.08
# Text: b'\x0c'
# 723 94 807 112
# Text Scale:  4.191616766467066
# Text Thickness:  3.36
# Text: b'\x0c'
# 692 391 810 419
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 432 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 507 87 587 109
# Text Scale:  0.7996801279488206
# Text Thickness:  1.0666666666666667
# Text: b'may\n\x0c'
# 629 391 690 418
# Text Scale:  0.4355898314767209
# Text Thickness:  0.61
# Text: b'en\nim\n\x0c'
# 465 430 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'pEACLUSIVE\n\x0c'
# 296 85 384 110
# Text Scale:  0.2587930831666863
# Text Thickness:  0.39111111111111113
# Text: b'\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\nwy\n\x0c'
# 271 389 456 419
# Text Scale:  0.38538455128739274
# Text Thickness:  0.5920000000000001
# Text: b'sia =\nDEE\nSUPER\nhelena\n\x0c'
# 456 389 606 419
# Text Scale:  0.4166203755138318
# Text Thickness:  0.631578947368421
# Text: b'r it\nR EACLUSIVE\n\x0c'
# 387 429 470 449
# Text Scale:  0.34577570404932506
# Text Thickness:  0.5107692307692308
# Text: b'STAR A\n\xe2\x80\x94\n\x0c'
# 237 85 293 110
# Text Scale:  2.7944111776447107
# Text Thickness:  2.24
# Text: b'\x0c'
# 275 36 362 73
# Text Scale:  4.341317365269461
# Text Thickness:  3.48
# Text: b'\x0c'
# 192 84 234 112
# Text Scale:  0.5247376311844077
# Text Thickness:  0.6719999999999999
# Text: b'ir\n\x0c'
# 596 89 637 110
# Text Scale:  0.2927734932876321
# Text Thickness:  0.41
# Text: b'\xe2\x80\x9cRt\n\x0c'
# 640 94 723 111
# Text Scale:  0.4149170165966806
# Text Thickness:  0.6036363636363636
# Text: b'\xe2\x80\x9cSPECI\n\x0c'
# 721 93 807 111
# Text Scale:  0.42991401719656064
# Text Thickness:  0.6254545454545455
# Text: b'LEDITION\n\x0c'
# 392 86 495 108
# Text Scale:  5.139720558882236
# Text Thickness:  4.12
# Text: b'\x0c'
# 692 391 810 419
# Text Scale:  5.888223552894212
# Text Thickness:  4.72
# Text: b'\x0c'
# 290 432 384 450
# Text Scale:  0.2937132858392701
# Text Thickness:  0.44235294117647056
# Text: b'SUPER:\noad\nez,\n\x0c'
# 507 87 587 109
# Text Scale:  0.9995002498750626
# Text Thickness:  1.28
# Text: b'ad\n\x0c'
# 295 85 389 109
# Text Scale:  0.5221061986225283
# Text Thickness:  0.752
# Text: b'ene\nrye\n\x0c'
# 629 391 690 418
# Text Scale:  0.38115471132216944
# Text Thickness:  0.5422222222222222
# Text: b'een\nim\n\x0c'
# 465 430 592 450
# Text Scale:  0.5290784869188468
# Text Thickness:  0.7815384615384615
# Text: b'pEACLUSIVE\n\x0c'
# 239 86 293 110
# Text Scale:  2.694610778443114
# Text Thickness:  2.16
# Text: b'\x0c'
# 271 389 456 419
# Text Scale:  0.4204163257885647
# Text Thickness:  0.6434782608695653
# Text: b'" =\nDEE\nSUPER\nhelena\n\x0c'
# 456 389 607 419
# Text Scale:  0.4440654040701094
# Text Thickness:  0.6711111111111111
# Text: b'Pit\nR EACLUSIVE\n\x0c'
# 387 429 470 449
# Text Scale:  0.3772041447009634
# Text Thickness:  0.5533333333333333
# Text: b'TENE:\n\xe2\x80\x94\n\x0c'
# 192 84 234 111
# Text Scale:  0.5247376311844077
# Text Thickness:  0.6719999999999999
# Text: b'it\n\x0c'
# 596 89 637 110
# Text Scale:  0.2927734932876321
# Text Thickness:  0.41
# Text: b'\xe2\x80\x9cRt\n\x0c'
# 492 178 535 273
# Text Scale:  0.307055127106541
# Text Thickness:  0.43
# Text: b'\xc2\xbb \xc2\xa2\n\x0c'
# ------------------------------------------------------------
# KeyboardInterrupt          Traceback (most recent call last)
# <ipython-input-10-76edd737d93c> in <module>
#      32         (123.68, 116.78, 103.94), swapRB=True, crop=False)
#      33     net.setInput(blob)
# ---> 34     (scores, geometry) = net.forward(layerNames)
#      35
#      36     # decode the predictions, then  apply non-maxima suppression to
#
# KeyboardInterrupt:
